# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d80717a-527a-45c5-ae73-ac6abd41b08d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d80717a-527a-45c5-ae73-ac6abd41b08d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d3d8c8ef-a9c6-4a7a-b3a2-5317246858e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3d8c8ef-a9c6-4a7a-b3a2-5317246858e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load Excel files into DataFrames
df1 = pd.read_excel("dataset_tripadvisor-reviews_2024-03-25_15-17-51-957fotoyok.xlsx")
df2 = pd.read_excel("xlsx2.xlsx")

# Identify missing details
missing_details = df2[~df2['id'].isin(df1['id'])]

# Merge DataFrames to add missing details
merged_df = pd.merge(df1, missing_details, on='id', how='left')

# Save the merged DataFrame to a new Excel file
merged_df.to_excel("merged_file.xlsx", index=False)

# %%
# Inspect merged DataFrame
print(merged_df.head())  # Display first few rows of the DataFrame
print(merged_df.info())  # Display DataFrame information

# Export merged DataFrame to Excel
merged_df.to_excel("merged_data.xlsx", index=False)
# Out:
#    helpfulVotes_x         id lang_x  locationId_x  ownerResponse_x  \
# 0               0  942684481     en      17767519              NaN
# 1               0  942525110     en      17767519              NaN
# 2               0  931659753     en      17767519              NaN
# 3               0  931296692     en      17767519              NaN
# 4               0  927302430     en      17767519              NaN
#
#   ownerResponse/connectionToSubject  ownerResponse/id ownerResponse/lang  \
# 0                               NaN               NaN                NaN
# 1                               NaN               NaN                NaN
# 2                               NaN               NaN                NaN
# 3                               NaN               NaN                NaN
# 4                               NaN               NaN                NaN
#
#   ownerResponse/publishedDate ownerResponse/responder  ... locationId_y  \
# ...

# %%
import pandas as pd

# Assuming merged_df is your merged DataFrame
try:
    # Export merged DataFrame to Excel
    merged_df.to_excel("merged_data.xlsx", index=False)
    print("Excel file 'merged_data.xlsx' has been successfully written.")
except Exception as e:
    print("An error occurred while writing the Excel file:", e)
# Out:
# Excel file 'merged_data.xlsx' has been successfully written.

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
merged_df.to_excel("/absolute/path/to/merged_data.xlsx", index=False)

# %%
import os
import pandas as pd

# Create directory if it doesn't exist
directory = "/absolute/path/to/"
if not os.path.exists(directory):
    os.makedirs(directory)

# Assuming merged_df is your merged DataFrame
# Export merged DataFrame to Excel
merged_df.to_excel(os.path.join(directory, "merged_data.xlsx"), index=False)

# %%
from google.colab import files

# Assuming "merged_data.xlsx" is the name of your Excel file
files.download("merged_data.xlsx")

# %%
df1.head()
# Out:
#    helpfulVotes         id lang  locationId  ownerResponse  \
# 0             0  942684481   en    17767519            NaN
# 1             0  942525110   en    17767519            NaN
# 2             0  931659753   en    17767519            NaN
# 3             0  931296692   en    17767519            NaN
# 4             0  927302430   en    17767519            NaN
#
#   ownerResponse/connectionToSubject  ownerResponse/id ownerResponse/lang  \
# 0                               NaN               NaN                NaN
# 1                               NaN               NaN                NaN
# 2                               NaN               NaN                NaN
# 3                               NaN               NaN                NaN
# 4                               NaN               NaN                NaN
#
#   ownerResponse/publishedDate ownerResponse/responder  ...  \
# 0                         NaN                     NaN  ...
# ...

# %%
df2.head()
# Out:
#           id                                                url  \
# 0  942684481  https://www.tripadvisor.com/ShowUserReviews-g1...
# 1  942525110  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  931659753  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3  931296692  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4  927302430  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                                title lang  locationId  \
# 0                                   Classy and tasty   en    17767519
# 1      Disappointingly Small portions but tasty food   en    17767519
# 2  Sublime, culinary delight in the centre of Hay...   en    17767519
# 3                                  Posh nosh in Hay    en    17767519
# 4                                    Fantastic meal.   en    17767519
#
#   publishedDate publishedPlatform  rating  helpfulVotes  \
# 0    2024-03-17             OTHER       5             0
# ...

# %%
import pandas as pd

# Assuming df1 and df2 are your DataFrames and 'ID' is the common column
merged_df = pd.merge(df1, df2[['id', 'text']], on='id', how='left')

# %%
merged_df.head()
# Out:
#    helpfulVotes         id lang  locationId  ownerResponse  \
# 0             0  942684481   en    17767519            NaN
# 1             0  942525110   en    17767519            NaN
# 2             0  931659753   en    17767519            NaN
# 3             0  931296692   en    17767519            NaN
# 4             0  927302430   en    17767519            NaN
#
#   ownerResponse/connectionToSubject  ownerResponse/id ownerResponse/lang  \
# 0                               NaN               NaN                NaN
# 1                               NaN               NaN                NaN
# 2                               NaN               NaN                NaN
# 3                               NaN               NaN                NaN
# 4                               NaN               NaN                NaN
#
#   ownerResponse/publishedDate ownerResponse/responder  ...  \
# 0                         NaN                     NaN  ...
# ...

# %%
import os
import pandas as pd

# Create directory if it doesn't exist
directory = "/absolute/path/to/"
if not os.path.exists(directory):
    os.makedirs(directory)

# Assuming merged_df is your merged DataFrame
# Export merged DataFrame to Excel
merged_df.to_excel(os.path.join(directory, "merged_data.xlsx"), index=False)

# %%
from google.colab import files

# Assuming "merged_data.xlsx" is the name of your Excel file
files.download("merged_data.xlsx")

# %%
# Merge DataFrames based on ID column
merged_df = pd.merge(df1, df2[['id', 'text']], on='id', how='left')

# Inspect merged DataFrame
print("\nMerged DataFrame:")
print(merged_df.head())
# Out:
# Merged DataFrame:
#    helpfulVotes         id lang  locationId  ownerResponse  \
# 0             0  942684481   en    17767519            NaN
# 1             0  942525110   en    17767519            NaN
# 2             0  931659753   en    17767519            NaN
# 3             0  931296692   en    17767519            NaN
# 4             0  927302430   en    17767519            NaN
#
#   ownerResponse/connectionToSubject  ownerResponse/id ownerResponse/lang  \
# 0                               NaN               NaN                NaN
# 1                               NaN               NaN                NaN
# 2                               NaN               NaN                NaN
# 3                               NaN               NaN                NaN
# 4                               NaN               NaN                NaN
#
#   ownerResponse/publishedDate ownerResponse/responder  ...  \
# 0                         NaN                     NaN  ...
# ...

# %%
text_column_merged_df = merged_df['text']

# %%
merged_df['text'] = df2['text']

# %%
print(merged_df.head())
# Out:
#    helpfulVotes         id lang  locationId  ownerResponse  \
# 0             0  942684481   en    17767519            NaN
# 1             0  942525110   en    17767519            NaN
# 2             0  931659753   en    17767519            NaN
# 3             0  931296692   en    17767519            NaN
# 4             0  927302430   en    17767519            NaN
#
#   ownerResponse/connectionToSubject  ownerResponse/id ownerResponse/lang  \
# 0                               NaN               NaN                NaN
# 1                               NaN               NaN                NaN
# 2                               NaN               NaN                NaN
# 3                               NaN               NaN                NaN
# 4                               NaN               NaN                NaN
#
#   ownerResponse/publishedDate ownerResponse/responder  ...  \
# 0                         NaN                     NaN  ...
# ...

# %%
merged_df['text']
# Out:
# 0       Recommend this small but nicely spaced restaur...
# 1       Very disappointed with my Tuna and Bread choic...
# 2       Had a wonderful Birthday meal for our daughter...
# 3       great taster menu selection, serving staff was...
# 4       Fantastic meal last night, every course a plea...
#                               ...
# 1229    A sense of calm enveloped us as we entered the...
# 1230    Delightful lunch.  Five courses, great value, ...
# 1231    Did the tasting menu last Friday 2/9, this is ...
# 1232    We had a fantastic meal enjoying super fresh f...
# 1233    A real gem of a restaurant. Unpretentious, int...
# Name: text, Length: 1234, dtype: object

# %%
import pandas as pd
from google.colab import files

# Assuming merged_df is your DataFrame
# Export merged_df to Excel
merged_df.to_excel("merged_data.xlsx", index=False)

# Download the Excel file
files.download("merged_data.xlsx")
